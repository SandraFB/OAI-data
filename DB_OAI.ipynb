# %% [markdown]
# <a href="https://colab.research.google.com/github/SandraFB/OAI-data/blob/main/DB_OAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Los archivos mostrados se encuentran en la ruta C:\Users\fubs9\R-Studio\OAICompleteData_SAS
#Importar librerías y deshabilitar los warnings generales
options(warn=-1)
library(haven)
#install.packages("dplyr")
install.packages("janitor")
library(dplyr)
library(janitor)
#install.packages("googledrive")
library("googledrive")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘snakecase’
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘janitor’
#
#
# The following objects are masked from ‘package:stats’:
#
#     chisq.test, fisher.test
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("googledrive") #only need to install occasionally install.packages(“httpuv”) 
library("googledrive") 
library("httpuv")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# Error in library("httpuv"): there is no package called ‘httpuv’
# Traceback:
#
# 1. library("httpuv")

# %%
getwd()
# Out:
# [1] "/content"

# %%
download.file('/content/data')
unzip(zipfile="/content/data.zip", exdir=".")
# Out:
# Error in download.file("/content/data"): argument "destfile" is missing, with no default
# Traceback:
#
# 1. download.file("/content/data")

# %% [markdown]
# # Lectura de base de datos OAI

# %% [markdown]
# ## General

# %%
#enroll <- read_sas("enrollees.sas7bdat",NULL)
meas <- read_sas("measinventory.sas7bdat",NULL)
outcome <- read_sas("outcomes99.sas7bdat",NULL)
subject <- read_sas("subjectchar00.sas7bdat",NULL)

# %% [markdown]
# ### MEAS Inventory

# %%
meas <- read_sas("measinventory.sas7bdat",NULL)

# %%
measi<- as.data.frame(meas)
remove_empty(measi)
# Out:
# value for "which" not specified, defaulting to c("rows", "cols")
#      id      VERSION cohort      V00AGE P02SEX P02RACE P02HISP VisitType12
# 1    9000099 11      Progression 59     1      1       0       Clinic visit
# 2    9000296 11      Incidence   69     1      1       0       Clinic visit
# 3    9000622 11      Progression 71     2      1       0       Clinic visit
# 4    9000798 11      Progression 56     1      1       0       Clinic visit
# 5    9001104 11      Incidence   72     2      1       0       Clinic visit
# 6    9001400 11      Incidence   75     2      1       0       Clinic visit
# 7    9001695 11      Incidence   52     2      1       0       Clinic visit
# 8    9001897 11      Incidence   72     1      1       0       Clinic visit
# 9    9002116 11      Progression 61     1      2       0       Clinic visit
# 10   9002316 11      Incidence   76     1      1       0       Clinic visit
# ...

# %%
inv= measi[ , c("id", "P02SEX","V00XRKLR","V00XRKLL","IndexKneeR","IndexKneeL","cohort")]
inv
# Out:
#      id      P02SEX V00XRKLR V00XRKLL IndexKneeR IndexKneeL cohort
# 1    9000099 1       2        3       Y          Y          Progression
# 2    9000296 1       2        3       N          N          Incidence
# 3    9000622 2       1        1       N          N          Progression
# 4    9000798 1       1        4       N          N          Progression
# 5    9001104 2       3        1       N          N          Incidence
# 6    9001400 2       1        1       N          N          Incidence
# 7    9001695 2       2        0       N          N          Incidence
# 8    9001897 1       3        1       N          N          Incidence
# 9    9002116 1       2        3       N          Y          Progression
# 10   9002316 1       1        0       N          N          Incidence
# 11   9002411 1       2        2       N          N          Incidence
# 12   9002430 1       2        3       N          N          Incidence
# ...

# %%
inv=rename(inv,ID=id,SEX=P02SEX,KLR0=V00XRKLR,KLL0=V00XRKLL,IDXKR=IndexKneeR,IDXKL=IndexKneeL,COHORT=cohort)

# %%
names(inv)
# Out:
# [1] "ID"     "SEX"    "KLR0"   "KLL0"   "IDXKR"  "IDXKL"  "COHORT"

# %%
write.csv(inv, file = "meas.csv",row.names = FALSE)

# %% [markdown]
# ## Complete Data

# %%
Fmts <- read_sas("formats.sas7bdat",NULL)
KSWLF <- read_sas("kMRI_SQ_WORMS_Link_Formats.sas7bdat",NULL)

Aceld06<- read_sas("acceldatabyday06.sas7bdat",NULL)
Aceld08<- read_sas("acceldatabyday08.sas7bdat",NULL)
Acelm06<- read_sas("acceldatabymin06.sas7bdat",NULL)
Acelm08<- read_sas("acceldatabymin08.sas7bdat",NULL)
Acel06<- read_sas("accelerometry06.sas7bdat",NULL)
Acel08<- read_sas("accelerometry08.sas7bdat",NULL)

AllC00<- read_sas("allclinical00.sas7bdat",NULL)
AllC01<- read_sas("allclinical01.sas7bdat",NULL)
AllC02<- read_sas("allclinical02.sas7bdat",NULL)
AllC03<- read_sas("allclinical03.sas7bdat",NULL)
AllC04<- read_sas("allclinical04.sas7bdat",NULL)
AllC05<- read_sas("allclinical05.sas7bdat",NULL)
AllC06<- read_sas("allclinical06.sas7bdat",NULL)
AllC07<- read_sas("allclinical07.sas7bdat",NULL)
AllC08<- read_sas("allclinical08.sas7bdat",NULL)
AllC09<- read_sas("allclinical09.sas7bdat",NULL)
AllC10<- read_sas("allclinical10.sas7bdat",NULL)
AllC11<- read_sas("allclinical11.sas7bdat",NULL)

Bio00<- read_sas("biomarkers00.sas7bdat",NULL)
Bio01<- read_sas("biomarkers01.sas7bdat",NULL)
Bio02<- read_sas("biomarkers02.sas7bdat",NULL)
Bio03<- read_sas("biomarkers03.sas7bdat",NULL)
Bio04<- read_sas("biomarkers04.sas7bdat",NULL)
Bio05<- read_sas("biomarkers05.sas7bdat",NULL)
Bio06<- read_sas("biomarkers06.sas7bdat",NULL)
Bio08<- read_sas("biomarkers08.sas7bdat",NULL)
Bio10<- read_sas("biomarkers10.sas7bdat",NULL)

BFnihJocoA<- read_sas("biospec_fnih_joco_assays.sas7bdat",NULL)
BFnihJocoD<- read_sas("Biospec_fnih_joco_demographics.sas7bdat",NULL)
BFnihLab00<- read_sas("biospec_fnih_labcorp00.sas7bdat",NULL)
BFnihLab01<- read_sas("biospec_fnih_labcorp01.sas7bdat",NULL)
BFnihLab03<- read_sas("biospec_fnih_labcorp03.sas7bdat",NULL)

Bone<- read_sas("boneancillarystudy.sas7bdat", NULL) 

ClinicalFnih<- read_sas("Clinical_fnih.sas7bdat",NULL)

Enroll <- read_sas("enrollees.sas7bdat",NULL)

####
##knee align not used
#flxr_kneealign_cooke01
#flxr_kneealign_cooke03
#flxr_kneealign_cooke05
#flxr_kneealign_cooke06
#flxr_kneealign_duryea01
#flxr_kneealign_duryea03
#flxr_kneealign_duryea05
#flxr_kneealign_duryea06
#####

KMriFBI00 <- read_sas("kmri_fnih_boneshape_imorphics00.sas7bdat",NULL)
KMriFBI01 <- read_sas("kmri_fnih_boneshape_imorphics01.sas7bdat",NULL)
KMriFBI03 <- read_sas("kmri_fnih_boneshape_imorphics03.sas7bdat",NULL)

KMriFQB00 <- read_sas("kmri_fnih_qcart_biomediq00.sas7bdat",NULL)
KMriFQB01 <- read_sas("kmri_fnih_qcart_biomediq01.sas7bdat",NULL)
KMriFQB03 <- read_sas("kmri_fnih_qcart_biomediq03.sas7bdat",NULL)

KMriFQC00 <- read_sas("kmri_fnih_qcart_Chondrometrics00.sas7bdat",NULL)
KMriFQC01 <- read_sas("kmri_fnih_qcart_Chondrometrics01.sas7bdat",NULL)
KMriFQC03 <- read_sas("kmri_fnih_qcart_Chondrometrics03.sas7bdat",NULL)

KMriFSQ00 <- read_sas("kmri_fnih_sbp_qmetrics00.sas7bdat",NULL)
KMriFSQ01 <- read_sas("kmri_fnih_sbp_qmetrics01.sas7bdat",NULL)
KMriFSQ03 <- read_sas("kmri_fnih_sbp_qmetrics03.sas7bdat",NULL)

KMriFMB00 <- read_sas("kmri_fnih_sq_moaks_bicl00.sas7bdat",NULL)
KMriFMB01 <- read_sas("kmri_fnih_sq_moaks_bicl01.sas7bdat",NULL)
KMriFMB03 <- read_sas("kmri_fnih_sq_moaks_bicl03.sas7bdat",NULL)

KMriPMB00 <- read_sas("kmri_poma_incoa_moaks_bicl.sas7bdat",NULL)
KMriPTC00 <- read_sas("kmri_poma_tkr_chondrometrics.sas7bdat",NULL)
KMriPTM00 <- read_sas("kmri_poma_tkr_moaks_bicl.sas7bdat",NULL)

KMriQE00 <- read_sas("kmri_qcart_eckstein00.sas7bdat",NULL)
KMriQE01 <- read_sas("kmri_qcart_eckstein01.sas7bdat",NULL)
KMriQE03 <- read_sas("kmri_qcart_eckstein03.sas7bdat",NULL)
KMriQE05 <- read_sas("kmri_qcart_eckstein05.sas7bdat",NULL)
KMriQE06 <- read_sas("kmri_qcart_eckstein06.sas7bdat",NULL)

KMriQL00 <- read_sas("kmri_qcart_link00.sas7bdat",NULL)
KMriQL03 <- read_sas("kmri_qcart_link03.sas7bdat",NULL)
KMriQL06 <- read_sas("kmri_qcart_link06.sas7bdat",NULL)

KMriQ00 <- read_sas("kmri_qcart_vs00.sas7bdat",NULL)
KMriQ01 <- read_sas("kmri_qcart_vs01.sas7bdat",NULL)

KMriSB00 <- read_sas("kmri_sq_bicl00.sas7bdat",NULL)
KMriSB03 <- read_sas("kmri_sq_bicl03.sas7bdat",NULL)

KMriSBB00 <- read_sas("kmri_sq_blksbml_bicl00.sas7bdat",NULL)
KMriSBB03 <- read_sas("kmri_sq_blksbml_bicl03.sas7bdat",NULL)

KMriSMB00 <- read_sas("kmri_sq_moaks_bicl00.sas7bdat",NULL)
KMriSMB01 <- read_sas("kmri_sq_moaks_bicl01.sas7bdat",NULL)
KMriSMB03 <- read_sas("kmri_sq_moaks_bicl03.sas7bdat",NULL)
KMriSMB05 <- read_sas("kmri_sq_moaks_bicl05.sas7bdat",NULL)
KMriSMB06 <- read_sas("kmri_sq_moaks_bicl06.sas7bdat",NULL)

KMriSWL00 <- read_sas("kmri_sq_worms_link00.sas7bdat",NULL)
KMriSWL03 <- read_sas("kmri_sq_worms_link03.sas7bdat",NULL)
KMriSWL06 <- read_sas("kmri_sq_worms_link06.sas7bdat",NULL)

KXFBD00 <- read_sas("kxr_fnih_bti_duke00.sas7bdat",NULL)
KXFBD01 <- read_sas("kxr_fnih_bti_duke01.sas7bdat",NULL)
KXFBD03 <- read_sas("kxr_fnih_bti_duke03.sas7bdat",NULL)

KXFD00 <- read_sas("kxr_fta_duryea00.sas7bdat",NULL)
KXFD01 <- read_sas("kxr_fta_duryea01.sas7bdat",NULL)
KXFD03 <- read_sas("kxr_fta_duryea03.sas7bdat",NULL)
KXFD05 <- read_sas("kxr_fta_duryea05.sas7bdat",NULL)
KXFD06 <- read_sas("kxr_fta_duryea06.sas7bdat",NULL)
KXFD08 <- read_sas("kxr_fta_duryea08.sas7bdat",NULL)
KXFD10 <- read_sas("kxr_fta_duryea10.sas7bdat",NULL)

KX00 <- read_sas("kxr_qjsw_duryea00.sas7bdat", NULL)
KX01 <- read_sas("kxr_qjsw_duryea01.sas7bdat", NULL)
KX03 <- read_sas("kxr_qjsw_duryea03.sas7bdat", NULL)
KX05 <- read_sas("kxr_qjsw_duryea05.sas7bdat", NULL)
KX06 <- read_sas("kxr_qjsw_duryea06.sas7bdat", NULL)
KX08 <- read_sas("kxr_qjsw_duryea08.sas7bdat", NULL)
KX10 <- read_sas("kxr_qjsw_duryea10.sas7bdat", NULL)

KXQRD00 <- read_sas("kxr_qjsw_rel_duryea00.sas7bdat",NULL)
KXQRD01 <- read_sas("kxr_qjsw_rel_duryea01.sas7bdat",NULL)
KXQRD03 <- read_sas("kxr_qjsw_rel_duryea03.sas7bdat",NULL)
KXQRD05 <- read_sas("kxr_qjsw_rel_duryea05.sas7bdat",NULL)

KRx00 <- read_sas("kxr_sq_bu00.sas7bdat",NULL)
KRx01 <- read_sas("kxr_sq_bu01.sas7bdat",NULL)
KRx03 <- read_sas("kxr_sq_bu03.sas7bdat",NULL)
KRx05 <- read_sas("kxr_sq_bu05.sas7bdat",NULL)
KRx06 <- read_sas("kxr_sq_bu06.sas7bdat",NULL)
KRx08 <- read_sas("kxr_sq_bu08.sas7bdat",NULL)
KRx10 <- read_sas("kxr_sq_bu10.sas7bdat",NULL)

KXSRB00 <- read_sas("kxr_sq_rel_bu00.sas7bdat",NULL)
KXSRB01 <- read_sas("kxr_sq_rel_bu01.sas7bdat",NULL)
KXSRB03 <- read_sas("kxr_sq_rel_bu03.sas7bdat",NULL)
KXSRB05 <- read_sas("kxr_sq_rel_bu05.sas7bdat",NULL)
KXSRB06 <- read_sas("kxr_sq_rel_bu06.sas7bdat",NULL)

Meas <- read_sas("measinventory.sas7bdat",NULL)

Mif00 <- read_sas("mif00.sas7bdat",NULL)
Mif01 <- read_sas("mif01.sas7bdat",NULL)
Mif02 <- read_sas("mif02.sas7bdat",NULL)
Mif03 <- read_sas("mif03.sas7bdat",NULL)
Mif04 <- read_sas("mif04.sas7bdat",NULL)
Mif05 <- read_sas("mif05.sas7bdat",NULL)
Mif06 <- read_sas("mif06.sas7bdat",NULL)
Mif08 <- read_sas("mif08.sas7bdat",NULL)
Mif10 <- read_sas("mif10.sas7bdat",NULL)

MRI00 <- read_sas("mri00.sas7bdat",NULL)
MRI01 <- read_sas("mri01.sas7bdat",NULL)
MRI02 <- read_sas("mri02.sas7bdat",NULL)
MRI03 <- read_sas("mri03.sas7bdat",NULL)
MRI04 <- read_sas("mri04.sas7bdat",NULL)
MRI05 <- read_sas("mri05.sas7bdat",NULL)
MRI06 <- read_sas("mri06.sas7bdat",NULL)
MRI08 <- read_sas("mri08.sas7bdat",NULL)
MRI10 <- read_sas("mri10.sas7bdat",NULL)

Outcome <- read_sas("outcomes99.sas7bdat",NULL)

SageS <- read_sas("sageancillarystudy.sas7bdat",NULL)
SageF <- read_sas("sageancillarystudy_formats.sas7bdat",NULL)

Subject <- read_sas("subjectchar00.sas7bdat",NULL)

X00 <- read_sas("xray00.sas7bdat",NULL)
X01 <- read_sas("xray01.sas7bdat",NULL)
X03 <- read_sas("xray03.sas7bdat",NULL)
X05 <- read_sas("xray05.sas7bdat",NULL)
X06 <- read_sas("xray06.sas7bdat",NULL)
X08 <- read_sas("xray08.sas7bdat",NULL)
X10 <- read_sas("xray10.sas7bdat",NULL)
# Out:
# Error: 'kMRI_SQ_WORMS_Link_Formats.sas7bdat' does not exist in current working directory ('/content').
# Traceback:
#
# 1. read_sas("kMRI_SQ_WORMS_Link_Formats.sas7bdat", NULL)
# 2. readr::datasource(data_file)
# 3. standardise_path(file)
# 4. check_path(path)
# 5. stop("'", path, "' does not exist", if (!is_absolute_path(path)) {
#  .     paste0(" in current working directory ('", getwd(), "')")
#  . }, ".", call. = FALSE)

# %% [markdown]
# ## All Clinical

# %% [markdown]
# ## Accelerometry

# %% [markdown]
# ## Biomarkers

# %%
bio0 <- read_sas("biomarkers00.sas7bdat",NULL)
bio1 <- read_sas("biomarkers01.sas7bdat",NULL)
bio3 <- read_sas("biomarkers03.sas7bdat",NULL)
bio5 <- read_sas("biomarkers05.sas7bdat",NULL)
bio6 <- read_sas("biomarkers06.sas7bdat",NULL)
bio8 <- read_sas("biomarkers08.sas7bdat",NULL)
bio10 <- read_sas("biomarkers10.sas7bdat",NULL)

# %%
bk0<- as.data.frame(bio0)
remove_empty(bk0)
bk1<- as.data.frame(bio1)
remove_empty(bk1)
bk3<- as.data.frame(bio3)
remove_empty(bk3)
bk5<- as.data.frame(bio5)
remove_empty(bk5)
bk6<- as.data.frame(bio6)
remove_empty(bk6)
bk8<- as.data.frame(bio8)
remove_empty(bk8)
bk10<- as.data.frame(bio10)
remove_empty(bk10)
# Out:
# value for "which" not specified, defaulting to c("rows", "cols")
#      ID      VERSION V00BLDCOLL V00BLDHRS1 V00BLDHRS2 V00BLDRAW1 V00BLDRAW2
# 1    9000099 0.2.3   1          35400      NA         1          NA
# 2    9000296 0.2.3   1          30780      NA         1          NA
# 3    9000622 0.2.3   1          33900      NA         1          NA
# 4    9000798 0.2.3   1          26400      NA         1          NA
# 5    9001104 0.2.3   1          35100      NA         1          NA
# 6    9001400 0.2.3   1          28200      NA         1          NA
# 7    9001695 0.2.3   1          29700      NA         1          NA
# 8    9001897 0.2.3   1          30300      NA         1          NA
# 9    9002116 0.2.3   1          25800      NA         1          NA
# 10   9002316 0.2.3   1          29400      NA         1          NA
# 11   9002411 0.2.3   1          28500      NA         1          NA
# 12   9002430 0.2.3   1          27000      NA         1          NA
# ...

# %%
write.csv(bk0, file = "biomarkers00.csv",row.names = FALSE)

# %%
names(bk10)
# Out:
# [1] "ID"         "VERSION"    "V10MRSEQNR" "V10MRSEQNL" "V10MRKSIDE"

# %%
bk_0= bk0[ , c("ID","V00BLDRAW1","V00CITRATE","V00EDTA","V00hoursp1","V00hrsuc1","V00MRSEQNL","V00MRSEQNR","V00MULTST1","V00pdate1","V00PLAQHR1","V00qovp1","V00SEAQHR1","V00SERUM","V00ucdate1","V00URINHR1","V00URINOB1","V00URNCOLL","V00vein1","V00void1")]
bk_1= bk1[ , c("ID","V01BLDRAW1","V01CITRATE","V01EDTA","V01hoursp1","V01hrsuc1","V01MRSEQNL","V01MRSEQNR","V01MULTST1","V01pdate1","V01PLAQHR1","V01qovp1","V01SEAQHR1","V01SERUM","V01ucdate1","V01URINHR1","V01URINOB1","V01URNCOLL","V01vein1","V01void1")]
bk_3= bk3[ , c("ID","V03BLDRAW1","V03CITRATE","V03EDTA","V03HOURSP1","V03HRSUC1","V03MRSEQNL","V03MRSEQNR","V03MULTST1","V03PDATE1","V03PLAQHR1","V03QOVP1","V03SEAQHR1","V03SERUM","V03UCDATE1","V03URINHR1","V03URINOB1","V03URNCOLL","V03VEIN1","V03VOID1")]
bk_5= bk5[ , c("ID","V05BLDRAW1","V05CITRATE","V05EDTA","V05HOURSP1","V05HRSUC1","V05MRSEQNL","V05MRSEQNR","V05MULTST1","V05PDATE1","V05PLAQHR1","V05QOVP1","V05SEAQHR1","V05SERUM","V05UCDATE1","V05URINHR1","V05URINOB1","V05URNCOLL","V05VEIN1","V05VOID1")]
bk_6= bk6[ , c("ID","V06BLDRAW1","V06CITRATE","V06EDTA","V06HOURSP1","V06HRSUC1","V06MRSEQNL","V06MRSEQNR","V06MULTST1","V06PDATE1","V06PLAQHR1","V06QOVP1","V06SEAQHR1","V06SERUM","V06UCDATE1","V06URINHR1","V06URINOB1","V06URNCOLL","V06VEIN1","V06VOID1")]
bk_8= bk8[ ,c("ID","V08BLDRAW1","V08CITRATE","V08EDTA","V08HOURSP1","V08HRSUC1","V08MRSEQNL","V08MRSEQNR","V08MULTST1","V08PDATE1","V08PLAQHR1","V08QOVP1","V08SEAQHR1","V08SERUM","V08UCDATE1","V08URINHR1","V08URINOB1","V08URNCOLL","V08VEIN1","V08VOID1")]
bk_10= bk10[ , c("ID","V10MRSEQNR","V10MRSEQNL")]#,"V10BLDRAW1","V10CITRATE","V10EDTA","V10HOURSP1","V10HRSUC1","V10MRSEQNL","V10MRSEQNR","V10MULTST1","V10PDATE1","V10PLAQHR1","V10QOVP1","V10SEAQHR1","V10SERUM","V10UCDATE1","V10URINHR1","V10URINOB1","V10URNCOLL","V10VEIN1","V10VOID1")]

#"V00BLDRAW1":EV:Phlebotomy: any blood drawn (first draw) (calc)
#"V00CITRATE":EV:Phlebotomy: which draw(s) citrate obtained at (calc)
#"V00EDTA": EV:Phlebotomy: which draw(s) EDTA obtained at (calc)
#"V00hoursp1":EV:Phlebotomy: how many hours passed since last ate any food before blood draw (first draw) (calc) 
#"V00hrsuc1": EV:Urine collection: hours since ate food before collection (first collection) (calc)
#"V00MRSEQNL": EV MRI:Left knee, number of unique OAI standard MRI sequences obtained (calc)
#"V00MRSEQNR": EV MRI:Right knee, number of unique OAI standard MRI sequences obtained (calc)
#"V00MULTST1":EV:Phlebotomy: traumatic venipuncture, multiple sticks (first draw) (calc)
#"V00pdate1":EV:Phlebotomy: date of blood draw (first draw) (calc)
#"V00PLAQHR1":EV:Laboratory processing: time at start of plasma aliquoting (first draw, 24-hr time) (calc)
#"V00qovp1":EV:Phlebotomy: quality of venipuncture (first draw) (calc)
#"V00SEAQHR1":EV:Laboratory processing: time at start of serum aliquoting (first draw, 24-hour time) (calc)
#"V00SERUM": EV:Phlebotomy: which draw(s) serum obtained at (calc)
#"V00ucdate1":EV:Urine collection: date of sample collection (first collection) (calc)
#"V00URINHR1":EV:Urine collection: time collected (first collection, 24-hr time) (calc)
#"V00URINOB1":EV:Urine collection: specimen obtained (first collection) (calc)
#"V00URNCOLL":EV:Urine collection: which sample collection(s) specimen obtained at (calc)
#"V00vein1":EV:Phlebotomy: traumatic venipuncture, vein hard to get (first draw) (calc)
#"V00void1":EV:Urine collection: which void(s) collected (first collection) (calc)

# %%
write.csv(bk_0, file = "bk00.csv",row.names = FALSE)
write.csv(bk_1, file = "bk01.csv",row.names = FALSE)
write.csv(bk_3, file = "bk03.csv",row.names = FALSE)
write.csv(bk_5, file = "bk05.csv",row.names = FALSE)
write.csv(bk_6, file = "bk06.csv",row.names = FALSE)
write.csv(bk_8, file = "bk08.csv",row.names = FALSE)
write.csv(bk_10, file = "bk10.csv",row.names = FALSE)

# %% [markdown]
# ## FNIH

# %% [markdown]
# ## Medicamentos MIF

# %%
mif0 <- read_sas("mif00.sas7bdat",NULL)
mif1 <- read_sas("mif01.sas7bdat",NULL)
mif3 <- read_sas("mif03.sas7bdat",NULL)
mif5 <- read_sas("mif05.sas7bdat",NULL)
mif6 <- read_sas("mif06.sas7bdat",NULL)
mif8 <- read_sas("mif08.sas7bdat",NULL)
mif10 <- read_sas("mif10.sas7bdat",NULL)

# %%
mif00<- as.data.frame(mif0)
remove_empty(mif00)
mif01<- as.data.frame(mif1)
remove_empty(mif01)
mif03<- as.data.frame(mif3)
remove_empty(mif03)
mif05<- as.data.frame(mif5)
remove_empty(mif05)
mif06<- as.data.frame(mif6)
remove_empty(mif06)
mif08<- as.data.frame(mif8)
remove_empty(mif08)
mif010<- as.data.frame(mif10)
remove_empty(mif010)
# Out:
# value for "which" not specified, defaulting to c("rows", "cols")
#       ID      VERSION V00MIFNAME                  V00FRMCODE V00MIFFREQ
# 1     9000296 0.2.2   ALLOPURINOL                 1          2
# 2     9000296 0.2.2   LISINOPRIL                  1          2
# 3     9000296 0.2.2   VIOXX                       1          2
# 4     9000622 0.2.2   AMOXICILLIN                 1          1
# 5     9000622 0.2.2   COUMADIN                    1          2
# 6     9000622 0.2.2   DIOVAN                      1          2
# 7     9000622 0.2.2   EVISTA                      1          2
# 8     9000622 0.2.2   FOSAMAX LIQUID              2          2
# 9     9000622 0.2.2   KLOR-CON                    1          2
# 10    9000622 0.2.2   TEMAZEPAM                   1          2
# 11    9000622 0.2.2   ZOCOR                       1          2
# 12    9001104 0.2.2   CAPTOPRIL                   1          2
# 13    9001104 0.2.2   CIPROFLOXACIN               1          2
# ...

# %%
write.csv(mif00, file = "mif00.csv",row.names = FALSE)

# %%
#mif00.V00MIFNAME=unclass(miff00.V00MIFNAME)
mifCX0= factor(mif00[ , "V00MIFNAME"])

# %%
mifCX00=unclass(mifCX0)

# %%
length(mifCX00)
# Out:
# [1] 15578

# %%
unique(mifCX0[unclass(mifCX0)])
# Out:
#   [1] METROLOTION                 METFORMIN
#   [3] FERROGELS FORTE             GLYBURIDE/METFORM
#   [5] AMLODIPINE                  GLIPIZIDE
#   [7] SYNTHROID                   LABETALOL
#   [9] AZITHROMYCIN                LIPITOR
#  [11] AMOXICILLIN 5OOMG PRN       TRIAMTERENE HCTZ
#  [13] DETROL                      INDOMETHACIN
#  [15] KETEK                       CIPROFLOXACIN
#  [17] CEPHALAXIN                  SPIRONOLACTONE
#  [19] IBUPROFEN                   VICODIN
#  [21] ZOCOR                       TETRACYCLINE
#  [23] PROZAC 10MG                 PROBENECID
#  [25] LESCOL                      METFORMIN 500MG
#  [27] COZAAR                      FOSAMAX
#  [29] L-THYROXINE                 LISINOPRIL
#  [31] MOTRIN                      ZOCOR TAB
#  [33] ATENOLOL                    ADVAIR
#  [35] PROPANOLOL                  LUMEGAN
#  [37] ZYRTEC                      XALATAN
#  [39] BACTRIM DS                  VESICAR
#  [41] THEOPHYLLINE                VASOTEC
# ...

# %%
mifCX0= factor(mif00[ , "V00MIFNAME"])
mifCX00=unclass(mifCX0)
mif_0= c(mif00[ , c("ID","V00MIFUSE")],mifCX00)



#mif_1= mif01[ , c("ID","V01BLDRAW1","V01CITRATE","V01EDTA","V01hoursp1","V01hrsuc1","V01MRSEQNL","V01MRSEQNR","V01MULTST1","V01pdate1","V01PLAQHR1","V01qovp1","V01SEAQHR1","V01SERUM","V01ucdate1","V01URINHR1","V01URINOB1","V01URNCOLL","V01vein1","V01void1")]
#mif_3= mif03[ , c("ID","V03BLDRAW1","V03CITRATE","V03EDTA","V03HOURSP1","V03HRSUC1","V03MRSEQNL","V03MRSEQNR","V03MULTST1","V03PDATE1","V03PLAQHR1","V03QOVP1","V03SEAQHR1","V03SERUM","V03UCDATE1","V03URINHR1","V03URINOB1","V03URNCOLL","V03VEIN1","V03VOID1")]
#mif_5= mif05[ , c("ID","V05BLDRAW1","V05CITRATE","V05EDTA","V05HOURSP1","V05HRSUC1","V05MRSEQNL","V05MRSEQNR","V05MULTST1","V05PDATE1","V05PLAQHR1","V05QOVP1","V05SEAQHR1","V05SERUM","V05UCDATE1","V05URINHR1","V05URINOB1","V05URNCOLL","V05VEIN1","V05VOID1")]
#mif_6= mif06[ , c("ID","V06BLDRAW1","V06CITRATE","V06EDTA","V06HOURSP1","V06HRSUC1","V06MRSEQNL","V06MRSEQNR","V06MULTST1","V06PDATE1","V06PLAQHR1","V06QOVP1","V06SEAQHR1","V06SERUM","V06UCDATE1","V06URINHR1","V06URINOB1","V06URNCOLL","V06VEIN1","V06VOID1")]
#mif_8= mif08[ ,c("ID","V08BLDRAW1","V08CITRATE","V08EDTA","V08HOURSP1","V08HRSUC1","V08MRSEQNL","V08MRSEQNR","V08MULTST1","V08PDATE1","V08PLAQHR1","V08QOVP1","V08SEAQHR1","V08SERUM","V08UCDATE1","V08URINHR1","V08URINOB1","V08URNCOLL","V08VEIN1","V08VOID1")]
#mif_10= mif010[ , c("ID","V10MRSEQNR","V10MRSEQNL")]#,"V10BLDRAW1","V10CITRATE","V10EDTA","V10HOURSP1","V10HRSUC1","V10MRSEQNL","V10MRSEQNR","V10MULTST1","V10PDATE1","V10PLAQHR1","V10QOVP1","V10SEAQHR1","V10SERUM","V10UCDATE1","V10URINHR1","V10URINOB1","V10URNCOLL","V10VEIN1","V10VOID1")]

#ID
#V00MIFUSE 
#mifCX00

# %%
write.csv(mif_0, file = "mif_0.csv",row.names = FALSE)

# %% [markdown]
# ## MR

# %% [markdown]
# ## XR

# %%
krx0 <- read_sas("kxr_sq_bu00.sas7bdat",NULL)
# Out:
# Error in read_sas("kxr_sq_bu00.sas7bdat", NULL): could not find function "read_sas"
# Traceback:

# %%
kx0<- as.data.frame(krx0)
remove_empty(kx0)
# Out:
# value for "which" not specified, defaulting to c("rows", "cols")
#       ID      SIDE READPRJ VERSION V00BARCDBU   V00XROSFM V00XRSCFM V00XRCYFM
# 1     9000099 1    15      0.8     016600839603  0         0         0
# 2     9000099 2    15      0.8     016600839603  0         0         0
# 3     9000296 1    15      0.8     016600175004  0         0         0
# 4     9000296 2    15      0.8     016600175004  0         0         0
# 5     9000622 1    15      0.8     016600831903 NA        NA        NA
# 6     9000622 2    15      0.8     016600831903 NA        NA        NA
# 7     9000798 1    15      0.8     016600162704  0         0         0
# 8     9000798 1    37      0.8     016600162704  0        NA        NA
# 9     9000798 2    15      0.8     016600162704  3         2         0
# 10    9001104 1    15      0.8     016600908703  2         2         0
# 11    9001104 2    15      0.8     016600908703  0         0         0
# ...

# %%
names(kx0)
# Out:
#  [1] "ID"         "SIDE"       "READPRJ"    "VERSION"    "V00BARCDBU"
#  [6] "V00XROSFM"  "V00XRSCFM"  "V00XRCYFM"  "V00XRJSM"   "V00XRCHM"
# [11] "V00XROSTM"  "V00XRSCTM"  "V00XRCYTM"  "V00XRATTM"  "V00XRKL"
# [16] "V00XROSFL"  "V00XRSCFL"  "V00XRCYFL"  "V00XRJSL"   "V00XRCHL"
# [21] "V00XROSTL"  "V00XRSCTL"  "V00XRCYTL"  "V00XRATTL"

# %%
kx0[ , c("ID", "SIDE","V00XRKL")]
# Out:
#       ID      SIDE V00XRKL
# 1     9000099 1    2
# 2     9000099 2    3
# 3     9000296 1    2
# 4     9000296 2    3
# 5     9000622 1    1
# 6     9000622 2    1
# 7     9000798 1    1
# 8     9000798 1    1
# 9     9000798 2    4
# 10    9001104 1    3
# 11    9001104 2    1
# 12    9001400 1    1
# 13    9001400 2    1
# 14    9001695 1    2
# 15    9001695 2    0
# 16    9001695 2    0
# 17    9001897 1    3
# 18    9001897 2    0
# 19    9001897 2    1
# 20    9002116 1    2
# 21    9002116 2    3
# 22    9002316 1    1
# 23    9002316 1    1
# 24    9002316 2    1
# 25    9002316 2    0
# 26    9002411 1    2
# 27    9002411 2    2
# 28    9002430 1    2
# 29    9002430 2    3
# 30    9002817 1    3
# ⋮     ⋮       ⋮    ⋮
# 12784 9997856 1    0
# 12785 9997856 1    0
# 12786 9997856 2    4
# 12787 9997869 1    2
# 12788 9997869 2    0
# 12789 9998089 1    2
# 12790 9998089 2    0
# 12791 9998089 2    0
# 12792 9998384 1    3
# 12793 9998384 2    2
# 12794 9999295 1    2
# ...

# %%
write.csv(kx0, file = "kxr_sq_bu00.csv",row.names = FALSE)

# %%
kx_0= kx0[ , c("ID", "SIDE","V00XRKL","V00XROSTL", "V00XROSFL", "V00XROSFM", "V00XROSTM", "V00XRSCFM", "V00XRSCTM", "V00XRJSM")]
kx_0
#"V00XROSTL": BL/FU kXR reading (BU): osteophytes (OARSI grades 0-3) tibia lateral compartment
#"V00XROSFL": BL/FU kXR reading (BU): osteophytes (OARSI grades 0-3) femur lateral compartment 
#"V00XROSFM": BL/FU kXR reading (BU): osteophytes (OARSI grades 0-3) femur medial compartment 
#"V00XROSTM": BL/FU kXR reading (BU): osteophytes (OARSI grades 0-3) tibia medial compartment 
#"V00XRSCFM": BL/FU kXR reading (BU): sclerosis (OARSI grades 0-3) femur medial compartment 
#"V00XRSCTM": BL/FU kXR reading (BU): sclerosis (OARSI grades 0-3) tibia medial compartment
#"V00XRJSM": BL/FU kXR reading (BU): joint space narrowing (OARSI grades 0-3) medial compartment
# Out:
#       ID      SIDE V00XRKL V00XROSTL V00XROSFL V00XROSFM V00XROSTM V00XRSCFM
# 1     9000099 1    2        1         2         0         1         0
# 2     9000099 2    3        1         2         0         0         0
# 3     9000296 1    2        0         0         0         1         0
# 4     9000296 2    3        0         0         0         1         0
# 5     9000622 1    1       NA        NA        NA        NA        NA
# 6     9000622 2    1       NA        NA        NA        NA        NA
# 7     9000798 1    1        0         0         0         0         0
# 8     9000798 1    1        0         0         0         0        NA
# 9     9000798 2    4        2         2         3         2         2
# 10    9001104 1    3        0         0         2         2         2
# 11    9001104 2    1        0         0         0         0         0
# 12    9001400 1    1       NA        NA        NA        NA        NA
# ...

# %%
write.csv(kx_0, file = "kx_bu00.csv",row.names = FALSE)

# %% [markdown]
# Guardaremos las otras visitas en csv con las mismas columnas

# %%
krx1 <- read_sas("kxr_sq_bu01.sas7bdat",NULL)
krx3 <- read_sas("kxr_sq_bu03.sas7bdat",NULL)
krx5 <- read_sas("kxr_sq_bu05.sas7bdat",NULL)
krx6 <- read_sas("kxr_sq_bu06.sas7bdat",NULL)
krx8 <- read_sas("kxr_sq_bu08.sas7bdat",NULL)
krx10 <- read_sas("kxr_sq_bu10.sas7bdat",NULL)

# %%
kx1<- as.data.frame(krx1)
remove_empty(kx1)
kx3<- as.data.frame(krx3)
remove_empty(kx3)
kx5<- as.data.frame(krx5)
remove_empty(kx5)
kx6<- as.data.frame(krx6)
remove_empty(kx6)
kx8<- as.data.frame(krx8)
remove_empty(kx8)
kx10<- as.data.frame(krx10)
remove_empty(kx10)
# Out:
# value for "which" not specified, defaulting to c("rows", "cols")
#      ID      SIDE readprj VERSION V01BARCDBU   V01XROSFM V01XRSCFM V01XRCYFM
# 1    9000099 1    15      1.8     016601653203  0         0         0
# 2    9000099 2    15      1.8     016601653203  0         0         0
# 3    9000296 1    15      1.8     016601140204  0         0         0
# 4    9000296 2    15      1.8     016601140204  0         1         0
# 5    9000622 1    15      1.8     016601597803 NA        NA        NA
# 6    9000622 2    15      1.8     016601597803 NA        NA        NA
# 7    9000798 1    15      1.8     016601230207  0         0         0
# 8    9000798 2    15      1.8     016601230207  3         3         1
# 9    9001104 1    15      1.8     016601674403  2         2         0
# 10   9001104 2    15      1.8     016601674403  0         0         0
# 11   9001400 1    15      1.8     016601319104 NA        NA        NA
# ...

# %%
kx_1= kx1[ , c("ID", "SIDE","V01XRKL","V01XROSTL", "V01XROSFL", "V01XROSFM", "V01XROSTM", "V01XRSCFM", "V01XRSCTM", "V01XRJSM")]
kx_3= kx3[ , c("ID", "SIDE","V03XRKL","V03XROSTL", "V03XROSFL", "V03XROSFM", "V03XROSTM", "V03XRSCFM", "V03XRSCTM", "V03XRJSM")]
kx_5= kx5[ , c("ID", "SIDE","v05XRKL","V05XROSTL", "V05XROSFL", "V05XROSFM", "V05XROSTM", "V05XRSCFM", "V05XRSCTM", "v05XRJSM")]
kx_6= kx6[ , c("ID", "SIDE","V06XRKL","V06XROSTL", "V06XROSFL", "V06XROSFM", "V06XROSTM", "V06XRSCFM", "V06XRSCTM", "V06XRJSM")]
kx_8= kx8[ , c("ID", "SIDE","V08XRKL","V08XROSTL", "V08XROSFL", "V08XROSFM", "V08XROSTM", "V08XRSCFM", "V08XRSCTM", "V08XRJSM")]
kx_10= kx10[ , c("ID", "SIDE","V10XRKL","V10XROSTL", "V10XROSFL", "V10XROSFM", "V10XROSTM", "V10XRSCFM", "V10XRSCTM", "V10XRJSM")]

# %%
kx_5=rename(kx_5,V05XRKL=v05XRKL,V05XRJSM=v05XRJSM)

# %%
write.csv(kx_1, file = "kx_bu01.csv",row.names = FALSE)
write.csv(kx_3, file = "kx_bu03.csv",row.names = FALSE)
write.csv(kx_5, file = "kx_bu05.csv",row.names = FALSE)
write.csv(kx_6, file = "kx_bu06.csv",row.names = FALSE)
write.csv(kx_8, file = "kx_bu08.csv",row.names = FALSE)
write.csv(kx_10, file = "kx_bu10.csv",row.names = FALSE)

# %% [markdown]
# # EDA

# %%
kx0<- as.data.frame(krx0)
remove_empty(kx0)

# %%
names(kx0)

# %%
kx0[ , c("ID", "SIDE","V00XRKL")]

# %%
kx_5=rename(kx_5,V05XRKL=v05XRKL,V05XRJSM=v05XRJSM)

# %%
write.csv(kx_1, file = "kx_bu01.csv",row.names = FALSE)

# %% [markdown]
# # OTRO EJERCICIO

# %%
kx00 <- read_sas("kxr_qjsw_duryea00.sas7bdat", NULL)
kx01 <- read_sas("kxr_qjsw_duryea01.sas7bdat", NULL)
kx03 <- read_sas("kxr_qjsw_duryea03.sas7bdat", NULL)
kx05 <- read_sas("kxr_qjsw_duryea05.sas7bdat", NULL)
kx06 <- read_sas("kxr_qjsw_duryea06.sas7bdat", NULL)
kx08 <- read_sas("kxr_qjsw_duryea08.sas7bdat", NULL)
kx010 <- read_sas("kxr_qjsw_duryea10.sas7bdat", NULL)
# Out:
# Error: 'kxr_qjsw_duryea00.sas7bdat' does not exist in current working directory ('/content').
# Traceback:
#
# 1. read_sas("kxr_qjsw_duryea00.sas7bdat", NULL)
# 2. readr::datasource(data_file)
# 3. standardise_path(file)
# 4. check_path(path)
# 5. stop("'", path, "' does not exist", if (!is_absolute_path(path)) {
#  .     paste0(" in current working directory ('", getwd(), "')")
#  . }, ".", call. = FALSE)

# %%
kx0<- as.data.frame(kx00)
remove_empty(kx0)
kx1<- as.data.frame(kx01)
remove_empty(kx1)
kx3<- as.data.frame(kx03)
remove_empty(kx3)
kx5<- as.data.frame(kx05)
remove_empty(kx5)
kx6<- as.data.frame(kx06)
remove_empty(kx6)
kx8<- as.data.frame(kx08)
remove_empty(kx8)
kx10<- as.data.frame(kx010)
remove_empty(kx10)
# Out:
# value for "which" not specified, defaulting to c("rows", "cols")
#      ID      SIDE readprj VERSION V00CFWDTH V00MCMJSW V00JSW175 V00JSW200
# 1    9000099 1    16      0.8      95.760   4.000     4.12      4.12
# 2    9000099 2    16      0.8      94.080   4.800     4.90      5.10
# 3    9000296 1    16      0.8      97.206   3.740     3.97      4.42
# 4    9000296 2    16      0.8      97.670   2.423     3.85      4.31
# 5    9000622 1    16      0.8      88.400   3.106     3.20      3.50
# 6    9000622 2    16      0.8      90.040   2.886     2.91      3.21
# 7    9000798 1    16      0.8     103.745   5.030     5.78      5.89
# 8    9000798 2    16      0.8     105.241   0.000     0.91      1.14
# 9    9001104 1    16      0.8      90.860   2.202     2.71      2.91
# 10   9001695 1    16      0.8      89.872   4.488     4.80      4.49
# 11   9001695 2    16      0.8      87.567   4.600     4.80      4.90
# 12   9001897 1    16      0.8     100.824   3.800     4.11      4.22
# ...

# %%
names(kx10)
# Out:
#  [1] "ID"         "side"       "readprj"    "VERSION"    "V10CFWDTH"
#  [6] "V10MCMJSW"  "V10JSW175"  "V10JSW200"  "V10JSW250"  "V10BARCDJD"
# [11] "V10JSW300"  "V10JSW225"  "V10TPCFDS"  "V10BMANG"   "V10JSW150"
# [16] "V10JSW275"  "V10LJSW850" "V10LJSW900" "V10LJSW700" "V10LJSW825"
# [21] "V10LJSW750" "V10LJSW875" "V10LJSW725" "V10LJSW775" "V10LJSW800"
# [26] "V10XMJSW"   "V10INCPLL"  "V10INCPLM"  "V10NOMMJSW" "V10NOLJSWX"
# [31] "V10MJSWBB"  "V10INCSTPS" "V10LTPMEBE" "V10NOMJSWX" "V10NOLMIN"
# [36] "V10IMPIXSZ"

# %%
encounter=visit
patientid=id
categorical=side,
# Out:
# value for "which" not specified, defaulting to c("rows", "cols")
#      ID      SIDE readprj VERSION V00CFWDTH V00MCMJSW V00JSW175 V00JSW200
# 1    9000099 1    16      0.8      95.760   4.000     4.12      4.12
# 2    9000099 2    16      0.8      94.080   4.800     4.90      5.10
# 3    9000296 1    16      0.8      97.206   3.740     3.97      4.42
# 4    9000296 2    16      0.8      97.670   2.423     3.85      4.31
# 5    9000622 1    16      0.8      88.400   3.106     3.20      3.50
# 6    9000622 2    16      0.8      90.040   2.886     2.91      3.21
# 7    9000798 1    16      0.8     103.745   5.030     5.78      5.89
# 8    9000798 2    16      0.8     105.241   0.000     0.91      1.14
# 9    9001104 1    16      0.8      90.860   2.202     2.71      2.91
# 10   9001695 1    16      0.8      89.872   4.488     4.80      4.49
# 11   9001695 2    16      0.8      87.567   4.600     4.80      4.90
# 12   9001897 1    16      0.8     100.824   3.800     4.11      4.22
# ...
